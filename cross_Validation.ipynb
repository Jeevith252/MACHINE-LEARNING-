# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevith252/MACHINE-LEARNING-/blob/main/cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

#Load data
df = sns.load_dataset("titanic")

#EDA
df.drop(["deck" , "embark_town" , "alive" , "class" , "who" , "adult_male"] ,axis = 1 , inplace=True)
df['age'].fillna(df['age'].mean() , inplace = True)
df.dropna(subset = ["embarked"] , inplace = True , axis = 0)

#Encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
columns = ["sex" ,"embarked", "alone"]
for col in columns:
    df[col] = encoder.fit_transform(df[col])

df = df.astype(int)

#FEATURE SCALING
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
column = ['pclass','age','sibsp', 'parch', 'fare','embarked']
df[column] = scaler.fit_transform(df[column])

# %% [markdown]
# ## **cross validation**

# %%
X = df.drop('survived' , axis = 1)
y = df['survived']

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC

model = SVC(kernel = 'rbf')

# %%
scores = cross_val_score(model , X , y , cv = 5 ,scoring = 'accuracy')

# %%
print(scores)
# Out:
# [0.81460674 0.8258427  0.79213483 0.80898876 0.86440678]

# %%
scores_avg = scores.mean()

print(scores_avg)
# Out:
# 0.8211959626737766
